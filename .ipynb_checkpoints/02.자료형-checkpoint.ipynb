# %%
#주석(단축키 ctrl + /)

#정수형
a = 123
b = -178
c = 0

print(a)
print(b)
print(c)
# Out:
# 123
# -178
# 0

# %%
#실수형
a = 1.2
b = 5.2E2 #5.2 X 10^2

print(a,b)
# Out:
# 1.2 520.0

# %%
#8진수 16진수
a = 0o177
print(a)

b = 0x8ff
print(b)
# Out:
# 127
# 2303

# %%
# 사칙연산
a = 3
b = 4
print(7 // 3) # 몫
print(a ** b) # 제곱
# Out:
# 2
# 81
